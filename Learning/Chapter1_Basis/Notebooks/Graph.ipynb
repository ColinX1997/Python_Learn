# %% [markdown]
# Could not using following imports since there is no Anaconda env set here
#
# But try to install all libs firstly

# %%
import pandas as pa
import matplotlib.pyplot as plt
import numpy as np

x = [21,22,23,4,5,6,77,88,9,10,324,51,5]
num_bins=5
plt.hist(x,num_bins)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import numpy as np
